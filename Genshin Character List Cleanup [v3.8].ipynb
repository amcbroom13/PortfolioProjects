# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\mcbro\Desktop\Genshin Character List [v3.8] - characters.csv")
df
# Out:
#                 name       HP    ATK    DEF      ascension_stat  stat_value  \
# 0         Arlecchino      NaN    NaN    NaN                 NaN         NaN
# 1          Charlotte      NaN    NaN    NaN                 NaN         NaN
# 2           Clorinde      NaN    NaN    NaN                 NaN         NaN
# 3           Freminet  12071.0  255.0  708.0                 ATK        0.24
# 4             Furina      NaN    NaN    NaN                 NaN         NaN
# ..               ...      ...    ...    ...                 ...         ...
# 78             Razor  11962.0  233.0  750.0  Physical DMG Bonus        0.30
# 79              Sayu  11853.0  244.0  744.0   Elemental Mastery       96.00
# 80  Shikanoin Heizou  10657.0  225.0  683.0     Anemo DMG Bonus        0.24
# 81            Xinyan  11201.0  248.0  798.0                 ATK        0.24
# 82            Yanfei   9352.0  240.0  586.0      Pyro DMG Bonus        0.24
#
# ...

# %%
df = df.dropna()
df
# Out:
#                   name       HP    ATK    DEF      ascension_stat  stat_value  \
# 12              Nahida  10360.0  298.0  630.0   Elemental Mastery     115.200
# 13    Kaedehara Kazuha  13348.0  296.0  806.0   Elemental Mastery     115.200
# 14  Sangonomiya Kokomi  13470.0  234.0  657.0     Hydro DMG Bonus       0.288
# 15               Yelan  14450.0  243.0  547.0           CRIT Rate       0.192
# 16           Alhaitham  13348.0  313.0  781.0    Dendro DMG Bonus       0.288
# ..                 ...      ...    ...    ...                 ...         ...
# 78               Razor  11962.0  233.0  750.0  Physical DMG Bonus       0.300
# 79                Sayu  11853.0  244.0  744.0   Elemental Mastery      96.000
# 80    Shikanoin Heizou  10657.0  225.0  683.0     Anemo DMG Bonus       0.240
# 81              Xinyan  11201.0  248.0  798.0                 ATK       0.240
# 82              Yanfei   9352.0  240.0  586.0      Pyro DMG Bonus       0.240
#
# ...

# %%
df[['HP', 'ATK', 'DEF', 'rarity']] = df[['HP', 'ATK', 'DEF', 'rarity']].astype(int)
df
# Out:
# C:\Users\mcbro\AppData\Local\Temp\ipykernel_6340\895909286.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['HP', 'ATK', 'DEF', 'rarity']] = df[['HP', 'ATK', 'DEF', 'rarity']].astype(int)
#                   name     HP  ATK  DEF      ascension_stat  stat_value  \
# 12              Nahida  10360  298  630   Elemental Mastery     115.200
# 13    Kaedehara Kazuha  13348  296  806   Elemental Mastery     115.200
# 14  Sangonomiya Kokomi  13470  234  657     Hydro DMG Bonus       0.288
# 15               Yelan  14450  243  547           CRIT Rate       0.192
# 16           Alhaitham  13348  313  781    Dendro DMG Bonus       0.288
# ..                 ...    ...  ...  ...                 ...         ...
# ...

# %%
df['use_and_own'] = df['usage_rate_38'] * df['own_rate']
df
# Out:
# C:\Users\mcbro\AppData\Local\Temp\ipykernel_6340\3046061495.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['use_and_own'] = df['usage_rate_38'] * df['own_rate']
#                   name     HP  ATK  DEF      ascension_stat  stat_value  \
# 12              Nahida  10360  298  630   Elemental Mastery     115.200
# 13    Kaedehara Kazuha  13348  296  806   Elemental Mastery     115.200
# 14  Sangonomiya Kokomi  13470  234  657     Hydro DMG Bonus       0.288
# 15               Yelan  14450  243  547           CRIT Rate       0.192
# 16           Alhaitham  13348  313  781    Dendro DMG Bonus       0.288
# ..                 ...    ...  ...  ...                 ...         ...
# ...

# %%
df['use_and_own'] = df['use_and_own'].round(3)
df
# Out:
# C:\Users\mcbro\AppData\Local\Temp\ipykernel_6340\1497514547.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['use_and_own'] = df['use_and_own'].round(3)
#                   name     HP  ATK  DEF      ascension_stat  stat_value  \
# 12              Nahida  10360  298  630   Elemental Mastery     115.200
# 13    Kaedehara Kazuha  13348  296  806   Elemental Mastery     115.200
# 14  Sangonomiya Kokomi  13470  234  657     Hydro DMG Bonus       0.288
# 15               Yelan  14450  243  547           CRIT Rate       0.192
# 16           Alhaitham  13348  313  781    Dendro DMG Bonus       0.288
# ..                 ...    ...  ...  ...                 ...         ...
# ...

# %%
df.to_excel(r"C:\Users\mcbro\Desktop\3.8_Genshin_Character_List.xlsx", index = False)
